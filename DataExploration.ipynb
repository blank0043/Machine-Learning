# %% [markdown]
# <a href="https://colab.research.google.com/github/blank0043/Machine-Learning/blob/main/DataExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data
# Import user data stored in a github, the user data can be found [here](https://github.com/blank0043/Machine-Learning/blob/main/user.tbl)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
user_data_url = 'https://raw.githubusercontent.com/blank0043/Machine-Learning/main/user.tbl'
users = pd.read_csv(user_data_url, sep='|')

# %% [markdown]
# #Cursory Data Exploration

# %% [markdown]
# The head method will list the first 5 rows of the dataframe

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# The tail method will list the last 5 rows of the dataframe

# %%
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# The index will return integers that represent the index of the first row and the last row and step defines what row will be read next

# %%
users.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %% [markdown]
# # Creating DataFrames
# One method of creating a dataframe is to leverage the pandas DatamFrame method and define the name of the column as a string and provide the data. The indeces are immutable values used to store and retrieve objects.

# %%
df = pd.DataFrame({'col': range(1, 21)})
df.index = pd.RangeIndex(start=0, stop=99, step=5)

# %%
df
# Out:
#     col
# 0     1
# 5     2
# 10    3
# 15    4
# 20    5
# 25    6
# 30    7
# 35    8
# 40    9
# 45   10
# 50   11
# 55   12
# 60   13
# 65   14
# 70   15
# 75   16
# 80   17
# 85   18
# 90   19
# 95   20

# %% [markdown]
# # Understanding the data that is stored in the dataframe
# DataFrames are a 2 dimensional  structure. The columns are labels for the data that are stored. To see the values of the columns the 'columns' function can be used

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# Columns are associated with a specific type of data that will be stored in rows. To understand the type of data stored in the column the 'dtypes' function can be used.

# %%
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# The shape of a dataframe is a tuple that represents the size

# %%
users.shape
# Out:
# (943, 5)

# %% [markdown]
# A numpy representation of the dataframe can be accessed via the values function

# %%
users.values
# Out:
# array([[1, 24, 'M', 'technician', '85711'],
#        [2, 53, 'F', 'other', '94043'],
#        [3, 23, 'M', 'writer', '32067'],
#        ...,
#        [941, 20, 'M', 'student', '97229'],
#        [942, 48, 'F', 'librarian', '78209'],
#        [943, 22, 'M', 'student', '77841']], dtype=object)

# %% [markdown]
# If you would like to print a summary of the dataframe, the 'info' function can be used

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
# user_id       943 non-null int64
# age           943 non-null int64
# gender        943 non-null object
# occupation    943 non-null object
# zip_code      943 non-null object
# dtypes: int64(2), object(3)
# memory usage: 36.9+ KB

# %% [markdown]
# # Working with data inside Dataframes
# A series with the data in a column can be obtained accessing the dataframe in similar fashion to a Dictionary object where the key is the value of the column.

# %%
series_from_df = users['gender']

# %%
series_from_df
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 938    F
# 939    M
# 940    M
# 941    F
# 942    M
# Name: gender, Length: 943, dtype: object

# %%
type(series_from_df)
# Out:
# pandas.core.series.Series

# %%
series_from_df.shape
# Out:
# (943,)

# %% [markdown]
# A dataframe can be formed from a column of data by wrapping the key in square brackets

# %%
df_from_df = users[['gender']]

# %%
df_from_df
# Out:
#     gender
# 0        M
# 1        F
# 2        M
# 3        M
# 4        F
# ..     ...
# 938      F
# 939      M
# 940      M
# 941      F
# 942      M
#
# [943 rows x 1 columns]

# %%
type(df_from_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_from_df.shape
# Out:
# (943, 1)

# %% [markdown]
# # Analyzing the data in a DataFrame

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
users.age.mean()
# Out:
# 34.05196182396607

# %%
users.age.hist()

# %%
users.gender.value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
users.gender.value_counts().plot(kind='bar')

# %%
users.age.value_counts()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
# 26    34
# 24    33
# 29    32
# 20    32
# 32    28
# 23    28
# 35    27
# 21    27
# 33    26
# 31    25
# 19    23
# 44    23
# 39    22
# 40    21
# 36    21
# 42    21
# 51    20
# 50    20
# 48    20
# 49    19
# 37    19
# 18    18
# 34    17
# 38    17
# 45    15
#       ..
# 47    14
# 43    13
# 46    12
# 53    12
# 55    11
# 41    10
# 57     9
# 60     9
# 52     6
# 56     6
# 15     6
# 13     5
# 16     5
# 54     4
# 63     3
# 14     3
# 65     3
# 70     3
# 61     3
# 59     3
# 58     3
# 64     2
# 68     2
# 69     2
# 62     2
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64

# %%
users.age.value_counts().index
# Out:
# Int64Index([30, 25, 22, 28, 27, 26, 24, 29, 20, 32, 23, 35, 21, 33, 31, 19, 44,
#             39, 40, 36, 42, 51, 50, 48, 49, 37, 18, 34, 38, 45, 17, 47, 43, 46,
#             53, 55, 41, 57, 60, 52, 56, 15, 13, 16, 54, 63, 14, 65, 70, 61, 59,
#             58, 64, 68, 69, 62, 11, 10, 73, 66,  7],
#            dtype='int64')

# %%
users.age.value_counts().sort_index().plot(kind='bar', figsize=(15, 15))
plt.xlabel('Age')
plt.ylabel('Number of Users')
plt.title('Number of Users Per Age')
# Out:
# Text(0.5, 1.0, 'Number of Users Per Age')

# %% [markdown]
# Exercise 1
#
# 1. Read drinks.csv into a DataFrame
# 2. print the head and tail of this DataFrame
# 3. Examine index, datatypes, and shape
# 4. Calculate the average beer servings for the entire data set
# 5. Count the number of occurrences of each "continent" value and see if it looks correct.

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
drinks_df = pd.read_csv('./data/drinks.csv')

# %%
drinks_df['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
drinks_df['continent'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks_df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
users[users['age'] < 20].head()
# Out:
#     user_id  age gender occupation zip_code
# 29       30    7      M    student    55436
# 35       36   19      F    student    93117
# 51       52   18      F    student    55105
# 56       57   16      M       none    84010
# 66       67   17      M    student    60402

# %%
mask = users.age < 20
users[mask].head()
# Out:
#     user_id  age gender occupation zip_code
# 29       30    7      M    student    55436
# 35       36   19      F    student    93117
# 51       52   18      F    student    55105
# 56       57   16      M       none    84010
# 66       67   17      M    student    60402

# %%
users[users['occupation'] == 'student'].head()
#mask = users.occupation == 'student'
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741
# 32       33   23      M    student    27510
# 35       36   19      F    student    93117

# %%
users.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
mask = (users.occupation == 'student') | (users.occupation == 'educator')
users[mask].head()
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 12       13   47      M   educator    29206
# 14       15   49      F   educator    97301
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#beer servings greater than 25 and continent in europe 
mask = (drinks_df.beer_servings > 25) & (drinks_df.continent == 'EU')
drinks_df[mask].head()
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 1   Albania             89              132             54
# 3   Andorra            245              138            312
# 9   Austria            279               75            191
# 15  Belarus            142              373             42
# 16  Belgium            295               84            212
#
#     total_litres_of_pure_alcohol continent
# 1                            4.9        EU
# 3                           12.4        EU
# 9                            9.7        EU
# 15                          14.4        EU
# 16                          10.5        EU

# %%
users.sort_values('age', inplace=True)

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 470      471   10      M        student    77459
# 288      289   11      M           none    94619
# 879      880   13      M        student    83702
# 608      609   13      F        student    55106
# 141      142   13      M          other    48118
# 673      674   13      F        student    55337
# 627      628   13      M           none    94306
# 812      813   14      F        student    02136
# 205      206   14      F        student    53115
# 886      887   14      F        student    27249
# 848      849   15      F        student    25652
# 280      281   15      F        student    06059
# 460      461   15      M        student    98102
# 617      618   15      F        student    44212
# 178      179   15      M  entertainment    20755
# 100      101   15      M        student    05146
# 56        57   16      M           none    84010
# ...

# %% [markdown]
# 1. Read ufo.csv into a DataFrame called "ufo".
# 2. Check the shape of the DataFrame.
# 3. What are the three most common colors reported?
# 4. For reports in VA, what's the most common city?
#
# **Count the number of missing values in each column.

# %%
ufo = pd.read_csv('./data/ufo.csv')

# %%
ufo.shape
# Out:
# (80543, 5)

# %%
ufo.columns
#colors_reported
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.columns = ['city', 'colors_reported', 'shape_reported', 'state', 'time']

# %%
mask = ufo['state'] == 'VA'
ufo[mask].city.value_counts().head(1)
# Out:
# Virginia Beach    110
# Name: city, dtype: int64

# %%
ufo.isnull().sum()
# Out:
# city                  47
# colors_reported    63509
# shape_reported      8402
# state                  0
# time                   0
# dtype: int64

# %%
df1 = ufo.dropna()

# %%
df1
# Out:
#                     city        colors_reported shape_reported state  \
# 12                Belton                    RED         SPHERE    SC
# 19            Bering Sea                    RED          OTHER    AK
# 36            Portsmouth                    RED      FORMATION    VA
# 44             Blairsden                  GREEN         SPHERE    CA
# 82              San Jose                   BLUE        CHEVRON    CA
# 84               Modesto                   BLUE           DISK    CA
# 91                Scipio                    RED         SPHERE    IN
# 111         Tarrant City                 ORANGE         CIRCLE    AL
# 129                 Napa                  GREEN           DISK    CA
# 138        Coeur d'Alene                 ORANGE          CIGAR    ID
# 152               Irving                   BLUE           DISK    KS
# 157           Greenville                  GREEN           DISK    MS
# 163          Green River                  GREEN         SPHERE    WY
# ...

# %%
drinks_df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks_df.continent.value_counts(dropna=False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
drinks_df.continent.isnull().sum()
# Out:
# 23

# %%
drinks_df[drinks_df.continent.notnull()].head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks_df['total_alcohol_servings'] = drinks_df.beer_servings + drinks_df.spirit_servings + drinks_df.wine_servings

# %%
drinks_df['mL'] = drinks_df.total_litres_of_pure_alcohol * 1000

# %%
drinks_df.drop(['total_litres_of_pure_alcohol'], axis=1, inplace=True)

# %%
drinks_df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks_df.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks_df.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_alcohol_servings           mL
# continent
# AF                      94.075472  3007.547170
# AS                     106.954545  2170.454545
# EU                     468.555556  8617.777778
# OC                     183.750000  3381.250000
# SA                     352.250000  6308.333333

# %%
drinks_df.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0
